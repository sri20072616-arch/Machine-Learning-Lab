# %%
import pandas as pd

S = pd.Series([10,20,30])
print(S)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
import pandas as pd

data = {'name': ['A', 'B'],
        'marks': [80, 90]}

df = pd.DataFrame(data)
print(df)
# Out:
#   name  marks
# 0    A     80
# 1    B     90
